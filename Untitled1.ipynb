# %% [markdown]
# <a href="https://colab.research.google.com/github/Popha/01.github.io/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def create_stack():#create stack
  stack = []
  return stack

def check_empty(stack):
  return len(stack) == 0

def push(stack, item):#
  stack.append(item)
  print("pushed item:" + item)

def pop(stack):#remove an element from the stack
  if (check_empty(stack)):
    return "stack is empty"

  return stack.pop()

stack = create_stack()
push(stack, str(1))
push(stack, str(2))
push(stack, str(3))
push(stack,str(3))
push(stack, str(4))
push(stack,str(4))
print("popped item:" + pop(stack))
print("stack after popping an element:" + str(stack))
# Out:
# pushed item:1
# pushed item:2
# pushed item:3
# pushed item:3
# pushed item:4
# pushed item:4
# popped item:4
# stack after popping an element:['1', '2', '3', '3', '4']

# %%
print("===Reversing data using stack===")
def reverse_string(s):
  return s[::-1]
text = "Hello World!"
reversed_text = reverse_string(text)
print(f"Original:{text}")
print(f"Reversed:{reversed_text}")
print()
# Out:
# ===Reversing data using stack===
# Original:Hello World!
# Reversed:!dlroW olleH

# %%
def reverse_string(s):
  return s[::-1]
text = "National University of Management"
reversed_text = reverse_string(text)
print(f"Original:{text}")
print(f"Reversed:{reversed_text}")
print()
# Out:
# Original:National University of Management
# Reversed:tnemeganaM fo ytisrevinU lanoitaN

# %%
def reverse_string(s):
  return s[::-1]
word = "Telegram"
reversed_word = reverse_string(word)
print(f"Reversed:{reversed_word}")
print()

word_lenght= len(word)
print(f"lenght:{len(word)}")
# Out:
# Reversed:margeleT
#
# lenght:8

# %% [markdown]
#  ** QUEUE**.Python queue Module Interface

# %%
import queue
import threading
import time
def demonstrate_builtin_queues():
  """Demonstrate python's built-in queue implementations"""

  print ("===PYTHON BUILT-IN QUEUE MODULE")

  #FIFO QUEUE
  print("\n1.FIFO Queue:")
  fifo_queue =queue.Queue(maxsize=3)

  #add items'
  for i in range(3):
    fifo




  #Get item
  while not fifo_queue.empty():
    item = fifo_queue.get()
    print(f"Got:{item}")
    fifo_queue.task_done()

  #2.LIFO queue(stack)
  print("\n2.LIFO Queue (Stack):")
  lifo_queue = queue.LifoQueue()

  for i in range(3):
    lifo_queue.put(i)
    print(f"Pushed:{i}")

  while not lifo_queue.empty():
    item = lifo_queue.get()
    print(f"Popped:{item}")

  #3 Priority Queue
  print("\n3.Prioity Queue:")
  priority_queue = queue.PriorityQueue()

  items = [(3,'low'), (1, 'High'), (2, 'Medium')]
  for priority, value in items:
      priority_queue.put((priority, value))
      print(f"Added:{value}(priority:{priority})")

  while not priority_queue.empty():
    prority, value = priority_queue.get()
    print(f"Processed:{value}(priority:{priority})")
